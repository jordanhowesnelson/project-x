# %% [markdown]
# # Problem Statement: Using Unsupervised Learning to Sort Service Categories

# %% [markdown]
# ### Import Libraries

# %%
import re
import pandas as pd
import multiprocessing
import numpy as np
import matplotlib.pyplot as plt

from progressbar import ProgressBar

pd.set_option("display.max_columns",500)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### Import Data

# %%
df2009 = pd.read_csv('./data/City_Service_Requests_in_2009.csv')
df2010 = pd.read_csv('./data/City_Service_Requests_in_2010.csv')
df2011 = pd.read_csv('./data/City_Service_Requests_in_2011.csv')
df2012 = pd.read_csv('./data/City_Service_Requests_in_2012.csv')
df2013 = pd.read_csv('./data/City_Service_Requests_in_2013.csv')
df2014 = pd.read_csv('./data/City_Service_Requests_in_2014.csv')
df2015 = pd.read_csv('./data/City_Service_Requests_in_2015.csv')
df2016 = pd.read_csv('./data/City_Service_Requests_in_2016.csv')
df2017 = pd.read_csv('./data/City_Service_Requests_in_2017.csv')
df2018 = pd.read_csv('./data/City_Service_Requests_in_2018.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#create main df
df = pd.DataFrame(df2009)

# %%
#append all years together
df = df.append([df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018])

# %%
#drop dup/irrev columns
df.drop(['X', 'Y', 'SERVICECODE', 'SERVICECALLCOUNT', 'XCOORD', 'YCOORD', 'SERVICEORDERSTATUS', 
         'SERVICEREQUESTID', 'CITY', 'STATE', 'MARADDRESSREPOSITORYID'], axis=1, inplace=True)

# %%
#how many entries are in the total df
df.shape
# Out:
# (2032019, 19)

# %%
#need to reindex so that all of the dfs don't have duplicate index values
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# - OBJECTID: claim id number
# - SERVICECODEDESCRIPTION: brief text description of service requested
# - SERVICETYPECODEDESCRIPTION: coded service
# - ORGANIZATIONACRONYM: organization responsible for this service
# - ADDDATE: data added to 311 log
# - RESOLUTIONDATE: data that the claim was (presumably) resolved (ticket was closed?)
# - SERVICEDUEDATE: date the claim service was due?
# - SERVICEORDERDATE: date the claim's service was ordered (pushed to the org docket?)
# - INSPECTIONFLAG: ?
# - INSPECTIONDATE: date the service was inspected
# - INSPECTORNAME: person who did the inspection
# - STATUS_CODE: ?
# - PRIORITY: ?
# - STREETADDRESS: address of claim?
# - LATITUDE
# - LONGITUDE
# - ZIPCODE
# - WARD
# - DETAILS: text summary of situation.

# %%
#are there any nulls?
df.isnull().sum()
# Out:
# OBJECTID                      0
# SERVICECODEDESCRIPTION        0
# SERVICETYPECODEDESCRIPTION    855
# ORGANIZATIONACRONYM           2
# ADDDATE                       0
# RESOLUTIONDATE                159854
# SERVICEDUEDATE                27388
# SERVICEORDERDATE              0
# INSPECTIONFLAG                0
# INSPECTIONDATE                1451445
# INSPECTORNAME                 1903391
# STATUS_CODE                   622674
# PRIORITY                      2679
# STREETADDRESS                 67584
# LATITUDE                      21851
# LONGITUDE                     21851
# ZIPCODE                       22729
# WARD                          30294
# DETAILS                       978416
# dtype: int64

# %% [markdown]
# # Cleaning & Exploring

# %%
df.SERVICECODEDESCRIPTION.value_counts()
# Out:
# Parking Meter Repair                                                  428395
# Bulk Collection                                                       296316
# Parking Enforcement                                                   195040
# Streetlight Repair Investigation                                      65795
# Pothole                                                               59250
# Emergency No-Parking Verification                                     55183
# Trash Collection - Missed                                             52282
# Sanitation Enforcement                                                48899
# Alley Cleaning                                                        47424
# Residential Parking Permit Violation                                  37716
# Recycling Collection - Missed                                         33368
# Tree Inspection                                                       32067
# Parking Meter Issues                                                  31523
# Street Cleaning                                                       31223
# Illegal Dumping                                                       30842
# Sidewalk Repair                                                       27785
# CONTAINER REMOVAL                                                     26983
# Abandoned Vehicle - On Public Property                                26587
# Roadway Signs                                                         24591
# Parking Meter Request                                                 24016
# Graffiti Removal                                                      22911
# Tree Pruning                                                          21744
# TRU Report                                                            20005
# Tree Planting                                                         19103
# Out of State Parking Violation (ROSA)                                 16856
# Rodent Inspection and Treatment                                       15926
# Tree Removal                                                          15715
# Snow/Ice Removal                                                      13413
# DMV - Drivers License/ID Issues                                       11649
# Supercan - Delivery                                                   10927
#                                                                       ...
# Speed Study Data & Map                                                2
# FEMS - Honor Guard (Do not use)                                       2
# DHS - Serious Medication Error                                        2
# xxx_Parking Meter - Bad Battery LOOK UP ONLY                          2
# xxx_RECEIPT - DV LOOK UP ONLY                                         2
# Christmas Tree Removal – Seasonal                                     1
# Outdoor Odor Tips                                                     1
# xxx_Parking Meter - Physical Damage LOOK UP ONLY                      1
# Bus Stop Change                                                       1
# General Environmental Concerns (DOEE)                                 1
# Sanitation Enforcement-Customer Follow up                             1
# xxx_ABC Follow-up LOOK UP ONLY                                        1
# DDS - Theft of Personal Property                                      1
# xxx_Littercans Service LOOK UP ONLY                                   1
# xxx_Parking Permit - Residential LOOK UP ONLY                         1
# DOEE - Outdoor Odor Tips                                              1
# Homeless Services - Hypothermia/Cold/Winter - Transport to Shelter    1
# xxx_Bulb Replacement LOOK UP ONLY                                     1
# xxx_Traffic Count Station Malfunction LOOK UP ONLY                    1
# xxx_Wires Down LOOK UP ONLY                                           1
# xxx_Curbs and Gutter - New LOOK UP ONLY                               1
# xxx_Public Space Obstructions (Under Investigation) LOOK UP           1
# Supercan Delivery - Customer Follow-up                                1
# SIGNS - Conflicting                                                   1
# xxx_Restore Electrical Service LOOK UP ONLY                           1
# zMoto test                                                            1
# Emergency - Transportation                                            1
# Bulk Collection - Update Existing Pickup                              1
# xxx_DPW MISC LOOK UP ONLY                                             1
# xxx_DHS MISC LOOK UP ONLY                                             1
# Name: SERVICECODEDESCRIPTION, Length: 316, dtype: int64

# %%
#how many different services are there?
df.SERVICECODEDESCRIPTION.value_counts().count()
#there are 316 different descriptions
# Out:
# 316

# %%
#what are the the ten most frequently asigned service codes?
df.SERVICECODEDESCRIPTION.value_counts(normalize=True).head(10)
#Parking Meter Repair                    0.210822
#Bulk Collection                         0.145823
#Parking Enforcement                     0.095983
#Streetlight Repair Investigation        0.032379
#Pothole                                 0.029158
#Emergency No-Parking Verification       0.027157
#Trash Collection - Missed               0.025729
#Sanitation Enforcement                  0.024064
#Alley Cleaning                          0.023338
#Residential Parking Permit Violation    0.018561
# Out:
# Parking Meter Repair                    0.210822
# Bulk Collection                         0.145823
# Parking Enforcement                     0.095983
# Streetlight Repair Investigation        0.032379
# Pothole                                 0.029158
# Emergency No-Parking Verification       0.027157
# Trash Collection - Missed               0.025729
# Sanitation Enforcement                  0.024064
# Alley Cleaning                          0.023338
# Residential Parking Permit Violation    0.018561
# Name: SERVICECODEDESCRIPTION, dtype: float64

# %%
#how many versions of "tree trimming" are there?
xmas_rows = [index for index, value in df.SERVICECODEDESCRIPTION.iteritems() if 'Christmas' in value]
df.iloc[xmas_rows].SERVICECODEDESCRIPTION.value_counts()
# Out:
# Christmas Tree Removal-Seasonal      705
# Christmas Tree Removal - Seasonal    531
# Christmas Tree Removal – Seasonal    1
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %%
#are there other versions of "tree"?
tree_rows = [index for index, value in df.SERVICECODEDESCRIPTION.iteritems() if 'Tree' in value]
df.iloc[tree_rows].SERVICECODEDESCRIPTION.value_counts() 
#these needs to be renamed to eliminate typo and doubles
# Out:
# Tree Inspection                      32067
# Tree Pruning                         21744
# Tree Planting                        19103
# Tree Removal                         15715
# xxx_Tree Trimming LOOK UP ONLY       2091
# Christmas Tree Removal-Seasonal      705
# Christmas Tree Removal - Seasonal    531
# Emergency - Trees                    460
# xxx_Tree Maintenance LOOK UP ONLY    3
# Christmas Tree Removal – Seasonal    1
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %%
#can I clean away the xxx_ so that it doesn't group in unsup learning?
df.SERVICECODEDESCRIPTION = df.SERVICECODEDESCRIPTION.map(lambda x: x.replace('xxx_', ''))
df.SERVICECODEDESCRIPTION = df.SERVICECODEDESCRIPTION.map(lambda x: x.replace(' LOOK UP ONLY', ''))

#how can this be cleaned to aggregate these more effeciently?

#is there an easier way to look at all of these categories to make sense of them?
#use unsup learning to sort SERVICECODEDESCRIPTION

# %% [markdown]
# ## Unsupervised Learning to Sort Service Codes

# %%
#import countvect to count test frequency
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate a CountVectorizer
vect = CountVectorizer(ngram_range=(1, 1))

#fit the strings
X = vect.fit_transform(df.SERVICECODEDESCRIPTION)

# %%
#initialize KMeans
from sklearn.cluster import KMeans

km = KMeans(n_clusters=150, n_jobs=-1)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=150, n_init=10, n_jobs=-1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
preds = km.labels_
labels = pd.DataFrame({'label_code':preds})
labels['service'] = df.SERVICECODEDESCRIPTION

for i in range(150):
    print(i)
    print(labels[labels.label_code == i].service.value_counts())
    print()
# Out:
# 0
# Sign Removal Investigation    1181
# Sign Removal investigation    658
# Sign Removal                  28
# Name: service, dtype: int64
#
# 1
# Parking Meter Repair                 428395
# Parking Meter - Flashing Fail        43
# Parking Meter - Multispace Repair    33
# Parking Meter - Coin Jam             23
# Parking Meter - Bad Battery          2
# Parking Meter - Physical Damage      1
# Name: service, dtype: int64
#
# 2
# Bulk Collection                             296316
# Bulk Collection - Unscheduled               94
# Bulk Collection - Update Existing Pickup    1
# Name: service, dtype: int64
#
# 3
# Parking Enforcement        195040
# Parking - Handicapped      48
# Parking Signs - Install    35
# Parking Regulations        15
# Name: service, dtype: int64
#
# 4
# Abandoned Vehicle - On Public Property    26587
# Name: service, dtype: int64
#
# 5
# Streetlight Repair Investigation    65795
# Name: service, dtype: int64
#
# 6
# Insects                                 1302
# Eviction                                224
# Pavement Markings                       182
# Bus Shelters                            179
# DDOT Citation                           107
# Bed Bugs                                96
# OUC NYE Test                            86
# Bicycles                                73
# Homeless Encampment                     68
# Recycling - Commercial Only             59
# Supercans                               56
# DOEE - Ban on Foam Food Containers      42
# Light-Infrastructure                    32
# Hoarding                                29
# FEMS - Honor Guard                      27
# Citation                                24
# DC 311 Service Requests                 23
# Streetcar                               19
# DCRA - MISC                             17
# Ticket Ombudsman                        17
# No Current to Light                     12
# Defective Fixure                        9
# FEMS - 20/20 Vision Plan                8
# TCC MISC                                8
# Survey SR Type                          7
# Recycling - School Program              7
# DDS - Serious Medication Error          7
# DHS - IRIS Update                       6
# Agency Contact                          5
# Building Code Violation                 5
# School Transit Subsidy Program          5
# SUPER - D/V SVCS SUPERVISOR ATTN REQ    5
# DDOT MISC                               4
# DCRA - Zoning                           3
# Public Space Permits                    3
# SalesForce DC311 Application Request    3
# DOH Misc                                3
# RECEIPT - DV                            2
# FEMS - Honor Guard (Do not use)         2
# DHS - Serious Medication Error          2
# Speed Study Data & Map                  2
# Restore Electrical Service              1
# DHS MISC                                1
# zMoto test                              1
# Littercans Service                      1
# Bus Stop Change                         1
# DDS - Theft of Personal Property        1
# ABC Follow-up                           1
# DPW MISC                                1
# Wires Down                              1
# Outdoor Odor Tips                       1
# Name: service, dtype: int64
#
# 7
# Emergency No-Parking Verification    55183
# Name: service, dtype: int64
#
# 8
# Residential Parking Permit Violation    37716
# Parking Permit - Residential            1
# Name: service, dtype: int64
#
# 9
# Tree Removal        15715
# Marking Removal     73
# Tree Maintenance    3
# Name: service, dtype: int64
#
# 10
# Sidewalk Repair    27785
# Sidewalk - New     114
# T-Plate Repair     7
# Name: service, dtype: int64
#
# 11
# Illegal Dumping            30842
# Illegal Fireworks          73
# Signs - Illegal Dumping    30
# Name: service, dtype: int64
#
# 12
# Sanitation Enforcement                         48899
# Sanitation Enforcement - Customer Follow-up    29
# Sanitation Enforcement-Customer Follow up      1
# Name: service, dtype: int64
#
# 13
# Recycling Collection - Missed                         33368
# Recycling Collection - Missed - Customer Follow-up    84
# Name: service, dtype: int64
#
# 14
# Trash Collection - Missed                       52282
# Trash Collection - Missed Customer Follow-up    79
# Name: service, dtype: int64
#
# 15
# Pothole    59250
# Name: service, dtype: int64
#
# 16
# Street Cleaning              31223
# Street Paving Schedule       93
# Street Lights - Burnt Out    28
# Street Lights - Damaged      6
# Name: service, dtype: int64
#
# 17
# DMV - Drivers License/ID Issues     11649
# DMV - Driver's License/ID Issues    15
# Name: service, dtype: int64
#
# 18
# Trash Cart - Delivery    8346
# Name: service, dtype: int64
#
# 19
# Out of State Parking Violation (ROSA)    16856
# Name: service, dtype: int64
#
# 20
# Tree Inspection       32067
# Housing Inspection    10
# Name: service, dtype: int64
#
# 21
# Roadway Signs       24591
# Fabricated Signs    11
# Name: service, dtype: int64
#
# 22
# Rodent Inspection and Treatment    15926
# Name: service, dtype: int64
#
# 23
# Alley Cleaning    47424
# Name: service, dtype: int64
#
# 24
# Dead Animal Collection    9035
# Name: service, dtype: int64
#
# 25
# Parking Meter Issues    31523
# Name: service, dtype: int64
#
# 26
# TRU Report                            20005
# Report Invalid Address to GIS Dept    2
# Name: service, dtype: int64
#
# 27
# Yard Waste - Missed                         7444
# Yard Waste- Missed                          6622
# Yard Waste - Missed - Customer Follow-up    99
# Name: service, dtype: int64
#
# 28
# Snow/Ice Removal    13413
# Name: service, dtype: int64
#
# 29
# CONTAINER REMOVAL                                26983
# Container Removal                                5278
# DOEE - Foam Ban / Food Container Requirements    13
# Name: service, dtype: int64
#
# 30
# Graffiti Removal                         22911
# Graffiti Removal - Customer Follow-up    8
# Name: service, dtype: int64
#
# 31
# DMV - Vehicle Registration Issues    7329
# DMV - Vehicle Inspection Issues      95
# Name: service, dtype: int64
#
# 32
# Traffic Signal Maintenance    6283
# Name: service, dtype: int64
#
# 33
# Parking Meter Request    24016
# Name: service, dtype: int64
#
# 34
# Sign Replacement    9858
# Bulb Replacement    1
# Name: service, dtype: int64
#
# 35
# Tree Planting    19103
# Name: service, dtype: int64
#
# 36
# Tree Pruning    21744
# Name: service, dtype: int64
#
# 37
# Recycling Cart Delivery    9520
# Name: service, dtype: int64
#
# 38
# Supercan - Delivery                       10927
# Supercan Delivery - Customer Follow-up    1
# Name: service, dtype: int64
#
# 39
# FEMS - Community Events                 5031
# FEMS - Community Events (Do not use)    19
# Name: service, dtype: int64
#
# 40
# Grass & Weeds Mowing    3320
# Name: service, dtype: int64
#
# 41
# Sidewalk Shoveling Enforcement Exemption    8113
# Name: service, dtype: int64
#
# 42
# How's My Driving - Complaint    4230
# Name: service, dtype: int64
#
# 43
# Rat Abatement    9760
# Name: service, dtype: int64
#
# 44
# Alleylight Repair Investigation    4409
# Name: service, dtype: int64
#
# 45
# FEMS - Smoke Alarm Application                 3683
# FEMS - Smoke Alarm Application (Do Not Use)    4
# Name: service, dtype: int64
#
# 46
# Residential Snow Removal (ServeDC)    6451
# Name: service, dtype: int64
#
# 47
# Alley Repair              8052
# Alley Temporary Repair    157
# Alley Light  Repair       6
# Name: service, dtype: int64
#
# 48
# Abandoned Vehicle - On Private Property    8333
# Name: service, dtype: int64
#
# 49
# Public Space Litter Can- Installation/Removal/Repair    1651
# Name: service, dtype: int64
#
# 50
# Dead Animal Pickup    8133
# Name: service, dtype: int64
#
# 51
# Supercan - Repair                         6640
# Supercan - Repair - Customer Follow-up    23
# Name: service, dtype: int64
#
# 52
# Curb and Gutter Repair                  3478
# Curb and Gutter Repair Investigation    92
# Curbs and Gutter - New                  1
# Name: service, dtype: int64
#
# 53
# Street Repair           8424
# Street Repair - Temp    156
# Name: service, dtype: int64
#
# 54
# Bicycle Issues    3559
# Name: service, dtype: int64
#
# 55
# Vacant Lot                                   5217
# DCRA - Vacant Building                       185
# XXX Vacant Property                          6
# XXX - Do Not Use - DCRA - Vacant Building    2
# Name: service, dtype: int64
#
# 56
# Traffic Signal Maintanence    3012
# Name: service, dtype: int64
#
# 57
# Snow/Ice Removal (Roadways AND Bridge walkways ONLY)    3015
# Name: service, dtype: int64
#
# 58
# Leaf Collection    1010
# Name: service, dtype: int64
#
# 59
# Traffic Calming                           910
# Traffic Calming Study                     19
# Traffic Calming Petition (Agency Only)    11
# Traffic Camera Location Map               5
# Traffic Count Station Malfunction         1
# Name: service, dtype: int64
#
# 60
# DC Government Information    2413
# Name: service, dtype: int64
#
# 61
# Traffic Signal Issue    6254
# Name: service, dtype: int64
#
# 62
# Wire Down / Power Outage    613
# Wire Down/Power Outage      506
# Name: service, dtype: int64
#
# 63
# DMV - Online Processing Issues      1104
# DMV - Online Processing Problems    15
# Name: service, dtype: int64
#
# 64
# Recycling Container Delivery                         2940
# Recycling Container Delivery - Customer Follow-up    7
# Name: service, dtype: int64
#
# 65
# Utility Repair Investigation    2839
# Utility Repair                  17
# Utility Repair - Major          4
# Name: service, dtype: int64
#
# 66
# Sign New Investigation    5239
# Sign New                  68
# Name: service, dtype: int64
#
# 67
# Public Space Litter Can-Collection    1984
# Name: service, dtype: int64
#
# 68
# DMV - Copy of Ticket    1667
# Name: service, dtype: int64
#
# 69
# DMV - Forms, Applications, and Manuals Request    1095
# DMV - Send Forms, Applications, Manuals           20
# Name: service, dtype: int64
#
# 70
# Traffic Safety Investigation    2315
# Name: service, dtype: int64
#
# 71
# Snow Removal Complaints for Sidewalks    1342
# Name: service, dtype: int64
#
# 72
# Sign Missing Investigation    2594
# Sign Missing                  68
# Name: service, dtype: int64
#
# 73
# DOEE - General Environmental Concerns    1087
# General Environmental Concerns (DOEE)    1
# Name: service, dtype: int64
#
# 74
# Abandoned Bicycle    3248
# ABANDONED BICYCLE    158
# Abandoned House      5
# Name: service, dtype: int64
#
# 75
# Marking Maintenance            1164
# Roadway Marking Maintenance    97
# Roadway Marking Removal        7
# Name: service, dtype: int64
#
# 76
# DOEE - Construction – Erosion Runoff    983
# DDOE - Construction – Erosion Runoff    2
# Name: service, dtype: int64
#
# 77
# Roadway Repair    3733
# Name: service, dtype: int64
#
# 78
# Recycling Cart -Repair     938
# Recycling Cart - Repair    741
# Name: service, dtype: int64
#
# 79
# DPW Correspondence Tracking    1419
# Name: service, dtype: int64
#
# 80
# Grass and Weeds Mowing    4417
# DCRA - Grass and Weeds    167
# Name: service, dtype: int64
#
# 81
# Trash Cart Repair    1999
# Name: service, dtype: int64
#
# 82
# Roadway Striping / Markings    1540
# Name: service, dtype: int64
#
# 83
# Tree Trimming    2091
# Name: service, dtype: int64
#
# 84
# Trash Container - Delivery                         1674
# Trash Container - Delivery - Customer Follow-up    10
# Name: service, dtype: int64
#
# 85
# DMV - Vehicle Title Issues    1898
# Name: service, dtype: int64
#
# 86
# Illegal Poster    1239
# Name: service, dtype: int64
#
# 87
# Alleylight Investigation                                    3657
# Public Space - Defects (Under Investigation) LOOK UP ONL    5
# Public Space Obstructions (Under Investigation) LOOK UP     1
# Name: service, dtype: int64
#
# 88
# Signed Street Sweeping Missed    535
# Name: service, dtype: int64
#
# 89
# CSR Reported Issues    1377
# Name: service, dtype: int64
#
# 90
# DOEE - Nuisance Odor Complaints    464
# Name: service, dtype: int64
#
# 91
# DCRA - Trash and Debris        744
# XXX_DCRA - Trash and Debris    7
# Name: service, dtype: int64
#
# 92
# Alleylight Repair    4083
# Name: service, dtype: int64
#
# 93
# How Is My Driving - Complaint    2079
# Name: service, dtype: int64
#
# 94
# Resident Parking Permit    1160
# Name: service, dtype: int64
#
# 95
# DMV - Processing Center Manager    666
# Name: service, dtype: int64
#
# 96
# Child Safety Seat Program    555
# Pedestrian Safety Program    195
# Name: service, dtype: int64
#
# 97
# Litter Can - Collection    1408
# Name: service, dtype: int64
#
# 98
# Bus/Rail Issues    1080
# Name: service, dtype: int64
#
# 99
# Parks and Recreation    527
# Name: service, dtype: int64
#
# 100
# Street Sweeping    987
# Name: service, dtype: int64
#
# 101
# Utility Repair Issue    1145
# Name: service, dtype: int64
#
# 102
# Christmas Tree Removal-Seasonal      705
# Christmas Tree Removal - Seasonal    531
# Christmas Tree Removal – Seasonal    1
# Name: service, dtype: int64
#
# 103
# Curb & Gutter Repair - Major    1225
# Name: service, dtype: int64
#
# 104
# Marking Installation    917
# Name: service, dtype: int64
#
# 105
# Insect Treatment    684
# Name: service, dtype: int64
#
# 106
# DMV - Refunds - Tickets                          625
# DMV - Tag Surrenders/Registration Fee Refunds    5
# Name: service, dtype: int64
#
# 107
# Safe Routes to School    305
# Name: service, dtype: int64
#
# 108
# DMV - Vehicle Insurance Lapse    570
# Name: service, dtype: int64
#
# 109
# Street Repairs    1096
# Name: service, dtype: int64
#
# 110
# DMV - Ticket Payment Dispute    434
# Name: service, dtype: int64
#
# 111
# Illegal Posters    693
# Name: service, dtype: int64
#
# 112
# Leaf Season Collection    1888
# Name: service, dtype: int64
#
# 113
# Abandoned Vehicle    1007
# Name: service, dtype: int64
#
# 114
# Emergency - Trees                  460
# Emergency - Supplies               16
# Emergency - Flooding               10
# Emergency - Heating and Cooling    4
# Emergency - Senior Assistance      3
# Emergency - Transportation         1
# Name: service, dtype: int64
#
# 115
# DMV - Driver and Vehicle Services Refund    265
# Name: service, dtype: int64
#
# 116
# School Crossing Guard            254
# School Crossing Guard Program    67
# Name: service, dtype: int64
#
# 117
# DMV - Hearings                      531
# DMV - Appeal                        60
# DMV - Offset                        54
# DMV - Offset Tracking               47
# DMV - Ticket Ombudsman              17
# DMV - Inspection Station Issues     10
# DMV  - Inspection Station Issues    5
# Name: service, dtype: int64
#
# 118
# Litter Can - Installation/Removal/Repair    844
# Name: service, dtype: int64
#
# 119
# FEMS - Fire Safety Education                 281
# FEMS - Fire Safety Education (Do Not Use)    4
# Name: service, dtype: int64
#
# 120
# Recycling Container -Repair    676
# Name: service, dtype: int64
#
# 121
# Bicycle Services    589
# Name: service, dtype: int64
#
# 122
# DOEE - Engine Idling Tips                                198
# DDOE - Engine Idling Tips                                79
# DOEE - Bag Law Tips                                      24
# DDOE - Construction Site Environmental Concern / Tips    24
# DDOE - Bag Law Tips                                      23
# DOEE - Foam Ban Tips                                     5
# DOEE - Outdoor Odor Tips                                 1
# Name: service, dtype: int64
#
# 123
# Snow Sidewalk Shoveling Enforcement Exemption    838
# Name: service, dtype: int64
#
# 124
# Signs Conflicting      641
# Conflicting Signs      21
# SIGNS - Conflicting    1
# Name: service, dtype: int64
#
# 125
# Snow Other                                     192
# Snow Towing                                    111
# Snow Ticket Reimbursement                      37
# Snow - Snow on Roadway                         24
# Snow Other (Snow Vehicle / Property Damage)    3
# Name: service, dtype: int64
#
# 126
# Parking Meter - No Time for Coin    159
# Name: service, dtype: int64
#
# 127
# Sidewalk Temporary Repair    445
# Name: service, dtype: int64
#
# 128
# DMV - Driver Record Issues    206
# Name: service, dtype: int64
#
# 129
# DMV - eTIMS Ticket Alert Services Issues    203
# Name: service, dtype: int64
#
# 130
# Marking Modification            433
# Roadway Marking Modification    29
# Name: service, dtype: int64
#
# 131
# Hypothermia Shelter Information    208
# Name: service, dtype: int64
#
# 132
# DMV - Adjudication Supervisor    309
# Name: service, dtype: int64
#
# 133
# Snow Metro Bus Shelter/Stop    186
# Name: service, dtype: int64
#
# 134
# Traffic Calming Investigation    891
# Name: service, dtype: int64
#
# 135
# Light-Overhead Guide Sign Lighting Repair    98
# Name: service, dtype: int64
#
# 136
# 311Force Reported Issues    317
# Name: service, dtype: int64
#
# 137
# Vacant Lot - Public Property Only    274
# Name: service, dtype: int64
#
# 138
# Trash Container Repair     365
# Trash Container- Repair    3
# Name: service, dtype: int64
#
# 139
# Homeless Services - Winter/Hypothermia Season                         128
# Homeless Services - Hypothermia/Cold/Winter - Protection Items        9
# Homeless Services - Hypothermia/Cold/Winter - Safety Checks           2
# Homeless Services - Hypothermia/Cold/Winter - Transport to Shelter    1
# Name: service, dtype: int64
#
# 140
# Light-Light Pole                       63
# Light-Tunnel/Underpass Light Repair    29
# Name: service, dtype: int64
#
# 141
# Emergency - Power Outage/Wires Down      114
# Emergency - Power Outage / Wires Down    19
# Name: service, dtype: int64
#
# 142
# Streetlight Repair                         597
# Streetlight Repair - Customer follow-up    17
# Name: service, dtype: int64
#
# 143
# Recycling- Information Request     92
# Recycling - Information Request    68
# Name: service, dtype: int64
#
# 144
# How Is My Driving - Compliment    109
# How's My Driving-Compliment       92
# How's My Driving - Compliment     33
# Name: service, dtype: int64
#
# 145
# Graffiti Removal - Paint Voucher Request               197
# Graffiti Removal-Paint Voucher Request                 51
# Graffiti Removal - Paint Voucher Customer Follow-up    3
# Name: service, dtype: int64
#
# 146
# Alley Repave    194
# Name: service, dtype: int64
#
# 147
# DMV - Drivers License/ID Reinstatement     168
# DMV - Driver's License/ID Reinstatement    3
# Name: service, dtype: int64
#
# 148
# Street Repaving    120
# Name: service, dtype: int64
#
# 149
# Parking Meter - Out of Order    96
# Name: service, dtype: int64

# %%
#can I write a function to create a new column that reports out the most frequent response?

#can I make a dictionary that can map the new column?
label_dict = {}
for i in range(150):
    label_dict[i] = str(labels[labels.label_code == i].service.value_counts().index[0])
label_dict
# Out:
# {0: 'Sign Removal Investigation',
#  1: 'Parking Meter Repair',
#  2: 'Bulk Collection',
#  3: 'Parking Enforcement',
#  4: 'Abandoned Vehicle - On Public Property',
#  5: 'Streetlight Repair Investigation',
#  6: 'Insects',
#  7: 'Emergency No-Parking Verification',
#  8: 'Residential Parking Permit Violation',
#  9: 'Tree Removal',
#  10: 'Sidewalk Repair',
#  11: 'Illegal Dumping',
#  12: 'Sanitation Enforcement',
#  13: 'Recycling Collection - Missed',
#  14: 'Trash Collection - Missed',
#  15: 'Pothole',
#  16: 'Street Cleaning',
#  17: 'DMV - Drivers License/ID Issues',
#  18: 'Trash Cart - Delivery',
#  19: 'Out of State Parking Violation (ROSA)',
#  20: 'Tree Inspection',
#  21: 'Roadway Signs',
#  22: 'Rodent Inspection and Treatment',
#  23: 'Alley Cleaning',
#  24: 'Dead Animal Collection',
#  25: 'Parking Meter Issues',
#  26: 'TRU Report',
#  27: 'Yard Waste - Missed',
#  28: 'Snow/Ice Removal',
#  29: 'CONTAINER REMOVAL',
#  30: 'Graffiti Removal',
#  31: 'DMV - Vehicle Registration Issues',
#  32: 'Traffic Signal Maintenance',
#  33: 'Parking Meter Request',
#  34: 'Sign Replacement',
#  35: 'Tree Planting',
#  36: 'Tree Pruning',
#  37: 'Recycling Cart Delivery',
#  38: 'Supercan - Delivery',
#  39: 'FEMS - Community Events',
#  40: 'Grass & Weeds Mowing',
#  41: 'Sidewalk Shoveling Enforcement Exemption',
#  42: "How's My Driving - Complaint",
#  43: 'Rat Abatement',
#  44: 'Alleylight Repair Investigation',
#  45: 'FEMS - Smoke Alarm Application',
#  46: 'Residential Snow Removal (ServeDC)',
#  47: 'Alley Repair',
#  48: 'Abandoned Vehicle - On Private Property',
#  49: 'Public Space Litter Can- Installation/Removal/Repair',
#  50: 'Dead Animal Pickup',
#  51: 'Supercan - Repair',
#  52: 'Curb and Gutter Repair',
#  53: 'Street Repair',
#  54: 'Bicycle Issues',
#  55: 'Vacant Lot',
#  56: 'Traffic Signal Maintanence',
#  57: 'Snow/Ice Removal (Roadways AND Bridge walkways ONLY)',
#  58: 'Leaf Collection',
#  59: 'Traffic Calming',
#  60: 'DC Government Information',
#  61: 'Traffic Signal Issue',
#  62: 'Wire Down / Power Outage',
#  63: 'DMV - Online Processing Issues',
#  64: 'Recycling Container Delivery',
#  65: 'Utility Repair Investigation',
#  66: 'Sign New Investigation',
#  67: 'Public Space Litter Can-Collection',
#  68: 'DMV - Copy of Ticket',
#  69: 'DMV - Forms, Applications, and Manuals Request',
#  70: 'Traffic Safety Investigation',
#  71: 'Snow Removal Complaints for Sidewalks',
#  72: 'Sign Missing Investigation',
#  73: 'DOEE - General Environmental Concerns',
#  74: 'Abandoned Bicycle',
#  75: 'Marking Maintenance',
#  76: 'DOEE - Construction – Erosion Runoff',
#  77: 'Roadway Repair',
#  78: 'Recycling Cart -Repair',
#  79: 'DPW Correspondence Tracking',
#  80: 'Grass and Weeds Mowing',
#  81: 'Trash Cart Repair',
#  82: 'Roadway Striping / Markings',
#  83: 'Tree Trimming',
#  84: 'Trash Container - Delivery',
#  85: 'DMV - Vehicle Title Issues',
#  86: 'Illegal Poster',
#  87: 'Alleylight Investigation',
#  88: 'Signed Street Sweeping Missed',
#  89: 'CSR Reported Issues',
#  90: 'DOEE - Nuisance Odor Complaints',
#  91: 'DCRA - Trash and Debris',
#  92: 'Alleylight Repair',
#  93: 'How Is My Driving - Complaint',
#  94: 'Resident Parking Permit',
#  95: 'DMV - Processing Center Manager',
#  96: 'Child Safety Seat Program',
#  97: 'Litter Can - Collection',
#  98: 'Bus/Rail Issues',
#  99: 'Parks and Recreation',
#  100: 'Street Sweeping',
#  101: 'Utility Repair Issue',
#  102: 'Christmas Tree Removal-Seasonal',
#  103: 'Curb & Gutter Repair - Major',
#  104: 'Marking Installation',
#  105: 'Insect Treatment',
#  106: 'DMV - Refunds - Tickets',
#  107: 'Safe Routes to School',
#  108: 'DMV - Vehicle Insurance Lapse',
#  109: 'Street Repairs',
#  110: 'DMV - Ticket Payment Dispute',
#  111: 'Illegal Posters',
#  112: 'Leaf Season Collection',
#  113: 'Abandoned Vehicle',
#  114: 'Emergency - Trees',
#  115: 'DMV - Driver and Vehicle Services Refund',
#  116: 'School Crossing Guard',
#  117: 'DMV - Hearings',
#  118: 'Litter Can - Installation/Removal/Repair',
#  119: 'FEMS - Fire Safety Education',
#  120: 'Recycling Container -Repair',
#  121: 'Bicycle Services',
#  122: 'DOEE - Engine Idling Tips',
#  123: 'Snow Sidewalk Shoveling Enforcement Exemption',
#  124: 'Signs Conflicting',
#  125: 'Snow Other',
#  126: 'Parking Meter - No Time for Coin',
#  127: 'Sidewalk Temporary Repair',
#  128: 'DMV - Driver Record Issues',
#  129: 'DMV - eTIMS Ticket Alert Services Issues',
#  130: 'Marking Modification',
#  131: 'Hypothermia Shelter Information',
#  132: 'DMV - Adjudication Supervisor',
#  133: 'Snow Metro Bus Shelter/Stop',
#  134: 'Traffic Calming Investigation',
#  135: 'Light-Overhead Guide Sign Lighting Repair',
#  136: '311Force Reported Issues',
#  137: 'Vacant Lot - Public Property Only',
#  138: 'Trash Container Repair',
#  139: 'Homeless Services - Winter/Hypothermia Season',
#  140: 'Light-Light Pole',
#  141: 'Emergency - Power Outage/Wires Down',
#  142: 'Streetlight Repair',
#  143: 'Recycling- Information Request',
#  144: 'How Is My Driving - Compliment',
#  145: 'Graffiti Removal - Paint Voucher Request',
#  146: 'Alley Repave',
#  147: 'DMV - Drivers License/ID Reinstatement',
#  148: 'Street Repaving',
#  149: 'Parking Meter - Out of Order'}
